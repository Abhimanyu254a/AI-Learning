# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GEMINI_API_KEY"] = os.getenv("GEMINI_API_KEY")

model = init_chat_model("google_genai:gemini-2.5-flash-lite")
response = model.invoke("Why do parrots Talk?")
response.content
# Out:
# 'Parrots talk for a variety of fascinating reasons, and it\'s not just about mimicking sounds. While mimicry is a significant part of it, the underlying motivations are more complex and rooted in their social nature and intelligence. Here\'s a breakdown of why parrots talk:\n\n**1. Social Bonding and Communication:**\n\n* **Flock Animals:** Parrots are highly social creatures that live in flocks in the wild. Communication is crucial for their survival and well-being. Talking, or vocalizing, allows them to:\n    * **Maintain Contact:** They use calls to stay in touch with their flock members, especially when foraging or flying, to avoid getting separated.\n    * **Alert to Danger:** Alarm calls warn others of predators.\n    * **Establish Dominance and Social Hierarchy:** Vocalizations can play a role in asserting their place within the flock.\n    * **Strengthen Bonds:** They engage in "vocal duets" and social grooming, which can involve vocalizations, to reinforce their relationship
# ...

# %% [markdown]
# ## Streaming and Batch
#
# ### Streaming
#
# Most models can stream their output content while it is being generated. By displaying output progressively, streaming significantly improves user experience, particularly for longer responses. Calling stream() returns an iterators that yields output chunks as they are produced. You can use a loop to process each chunks in real time.

# %%
model.invoke("Write me a 200 words paragraph on Artifical Intelligence")
# Out:
# AIMessage(content="Artificial Intelligence (AI) is a transformative field focused on creating systems that can perform tasks typically requiring human intelligence. This encompasses a broad spectrum of capabilities, from learning and problem-solving to perception and decision-making. Machine learning, a core component of AI, allows systems to improve their performance on a task with experience, without being explicitly programmed for every scenario. Deep learning, a subset of machine learning, utilizes complex neural networks to process vast amounts of data, enabling breakthroughs in areas like image recognition, natural language processing, and autonomous systems. AI's applications are rapidly expanding, revolutionizing industries such as healthcare, finance, transportation, and entertainment, promising enhanced efficiency, personalized experiences, and novel solutions to complex global challenges. However, the rise of AI also necessitates careful consideration of ethical implicatio
# ...

# %%
for chunk in model.stream("Write me a 200 words paragraph on AI"):
    print(chunk.text, end='|',flush=True)
# Out:
# Artificial intelligence (AI) is| rapidly transforming our world, mimicking human cognitive functions like learning, problem-solving,| and decision-making. From sophisticated algorithms powering search engines and recommendation systems to the development of autonomous vehicles and advanced medical diagnostics, AI's applications are vast and ever-expanding. Machine learning, a subset of AI, allows systems to learn from data without explicit| programming, enabling them to improve their performance over time. Natural language processing (NLP) empowers machines to understand and generate human language, paving the way for conversational agents and sophisticated text analysis. While AI offers immense potential for innovation and efficiency, it also raises important| ethical considerations regarding bias, privacy, and job displacement, necessitating careful development and responsible deployment. The ongoing evolution of AI promises to redefine industries, enhance human capabilities, and r
# ...

# %%
for chunk in model.stream("Write do parrots have colorful feathers?"):
    print(chunk.text, end='|',flush=True)

# %% [markdown]
# ## Batch
#
# Batching a collection of independent requests to a model can significantly improve performance and reduce costs, as the processing can be done in parallel.

# %%
response = model.batch([
    "what do parrots have colorful feathers?",
    "how do airplanes fly?",
    "What is quantum computing?"
],
    config={
        'max_concurrency'=5 
    }
)
