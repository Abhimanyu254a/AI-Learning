# %% [markdown]
# ## Models Integration with OpenAI, Google Gemini and GROQ

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GEMINI_API_KEY"]=os.getenv("GEMINI_API_KEY");

# %% [markdown]
# ## This is for the OpenAI one

# %%
from langchain.chat_models import init_chat_model
# model=init_chat_model("gpt-5") #-> you can add this one
# model
# response=model.invoke("Hello, How are you?")
# response

# %% [markdown]
# ## This is for the Google Gemini model

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GEMINI_API_KEY"] = os.getenv("GEMINI_API_KEY")

model = init_chat_model("google_genai:gemini-2.5-flash-lite")
response = model.invoke("Why do parrots Talk?")
response.content
# Out:
# 'Parrots talk for a variety of reasons, and it\'s a fascinating interplay of their biology, social needs, and cognitive abilities. Here\'s a breakdown of the main drivers:\n\n**1. Social Bonding and Communication:**\n\n* **Flock Animals:** Parrots are highly social creatures that live in large flocks in the wild. Talking is a crucial part of maintaining social bonds, coordinating activities, and warning each other of danger.\n* **Mimicry as a Social Tool:** In the wild, parrots mimic the calls of other parrots in their flock. This helps them identify their group, reinforce social connections, and understand the nuances of their social hierarchy. When they mimic other sounds, it\'s essentially an extension of this natural behavior.\n* **Seeking Attention and Interaction:** In a captive environment, a parrot\'s "flock" is its human family. Talking is a way for them to get your attention, solicit interaction, and feel like a part of the group. They learn that making sounds often leads to a positive response from you.\n\n**2. Cognitive Abilities and Intelligence:**\n\n* **Complex Vocal Learning:** Parrots are among the most intelligent birds and possess a remarkable ability for vocal learning. This means they can learn and reproduce new sounds, not just innate calls. This ability is essential for their survival and social integration in the wild.\n* **Problem-Solving and Learning:** Their intelligence allows them to understand cause and effect. They learn that certain sounds or phrases elicit specific reactions (e.g., "hello" gets a greeting, "treat" gets a tasty morsel).\n* **Cognitive Stimulation:** Talking provides mental stimulation for parrots. It\'s a way for them to engage their brains and practice their learned behaviors.\n\n**3. Mimicry and Imitation:**\n\n* **Natural Tendency to Imitate:** As mentioned, mimicry is a core part of their natural communication. They are wired to pick up sounds from their environment.\n* **Testing Boundaries and Learning:** When a parrot imitates you, they are not just repeating words. They are often testing their vocal abilities, seeing how you react, and learning about the world around them.\n* **Association:** They learn to associate sounds with contexts and outcomes. If they hear you say "good boy" when you give them a treat, they\'ll start to associate that phrase with positive reinforcement.\n\n**4. Boredom and Lack of Stimulation:**\n\n* **Under-stimulated Parrots May Talk More:** If a parrot is bored, lonely, or not getting enough mental or social stimulation, they might resort to talking more as a way to entertain themselves or to try and elicit a reaction from their owners.\n\n**5. Expressing Emotions (to an extent):**\n\n* **While not conscious "talking" in the human sense, parrots can use vocalizations to express a range of emotions.** A happy parrot might whistle or chirp cheerfully, while a stressed or scared parrot might squawk loudly. The words they learn can become associated with these emotional states. For example, they might say "I\'m happy" when they are content.\n\n**In Summary:**\n\nParrots talk primarily because they are:\n\n*   **Social animals** who use vocalizations to bond and communicate.\n*   **Highly intelligent** with a remarkable capacity for vocal learning.\n*   **Natural mimics** who learn by imitating sounds in their environment.\n*   **Seeking interaction and attention** from their human flock.\n\nIt\'s important to remember that while parrots can mimic human speech, they don\'t understand the meaning of words in the same way humans do. They learn associations between sounds and contexts, and their "talking" is a learned behavior that serves their social and cognitive needs.'
